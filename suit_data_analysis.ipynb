# %% [markdown]
# # **Solar Data Analysis**
#
# Welcome to the Aditya L1 SUIT (Solar Ultraviolet Imaging Telescope) data analysis workshop. In this workshop, you will learn how to analyze SUIT data from the Aditya L1 mission using Python and some important libraries like NumPy, Sunpy, and matplotlib. We will work on Google Colab for simplicity and accessibility.
#
# ### Agenda:
# 1. Python Basics
# 2. Data Visualization with matplotlib
# 3. SUIT Data Analysis Exercises

# %% [markdown]
# ## Section 1: Python Basics
#
# We will start by refreshing some basic Python concepts. If you're new to programming or need a quick revision, this section will help.
#
# ### Key concepts:
# - Variables and data types
# - Loops
# - Lists

# %%
#Variables and data types
x = 10 #assigning values to variables
y = 3.5
name = "Aditya L1"
print(f"Integer: {x}, Float: {y}, String: {name}")
# Out:
# Integer: 10, Float: 3.5, String: Aditya L1

# %%
# Lists and dictionaries
planets = ["Mercury", "Venus", "Earth", "Mars"]

print(planets)
print(planets[2:4])
# Out:
# ['Mercury', 'Venus', 'Earth', 'Mars']
# ['Earth', 'Mars']

# %% [markdown]
# ### Mathematical operations

# %%
a= 55.7
b= 6.3
sum= a+b
dif= a-b
mul= a*b
div= a/b
rem= a%b #remainder
pow= 2**3 #Power is given as **
print(sum)
print("The difference is", dif, "and the product is", mul)
print("We get "+str(div) + " upon division")
print("The remainder is", rem)
print("Power: ", pow)
# Out:
# 62.0
# The difference is 49.400000000000006 and the product is 350.91
# We get 8.841269841269842 upon division
# The remainder is 5.300000000000004
# Power:  8

# %% [markdown]
# ### Loops in python

# %%
# For loop
for i in range(3):
    print(i,"Welcome to HBCSE!")
# Out:
# 0 Welcome to HBCSE!
# 1 Welcome to HBCSE!
# 2 Welcome to HBCSE!

# %%
# While loop
x=0
while x <10:
  print(x,'is still less than 10')
  x= x+1

print(x, 'is now 10')
# Out:
# 0 is still less than 10
# 1 is still less than 10
# 2 is still less than 10
# 3 is still less than 10
# 4 is still less than 10
# 5 is still less than 10
# 6 is still less than 10
# 7 is still less than 10
# 8 is still less than 10
# 9 is still less than 10
# 10 is now 10

# %%
import numpy as np
a=67

sqrt= np.sqrt(a) #Square root can be done with numpy package
print(sqrt)

pi= np.pi #Values of constants like pi can be pulled from numpy
print(pi)

num_ls=[2,4,5,7,8,24]
print("Mean=", np.mean(num_ls))
print("Median=", np.median(num_ls))
print("Standard Deviation=", np.std(num_ls))
# Out:
# 8.18535277187245
# 3.141592653589793
# Mean= 8.333333333333334
# Median= 6.0
# Standard Deviation= 7.272474743090476

# %% [markdown]
# ### Exercise 1: Python Basics
#
# 1. Create a list of five planets and print the third planet in the list.
# 2. Print the first 10 even number using `for loop` and `while loop`.

# %% [markdown]
# ------------------------------------------------------------------------------------

# %% [markdown]
# # **Solar Data Analysis**
# *Skip if packages are installed*

# %% [markdown]
#    **Pre-requisites:**
#
#  **1. NumPy**
#
#  **2. Matplotlib**
#
#  **3. SunPy**
#
#
#
#  Now, we need to install SunPy first.
#  '!' runs this command in the backend terminal instead of the notebook itself, and installs SunPy.

# %%
# !pip install sunpy[all]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sunpy[all] in /home/adithya/.local/lib/python3.10/site-packages (6.0.4)
# Requirement already satisfied: astropy>=5.3.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (6.1.4)
# Requirement already satisfied: numpy>=1.23.5 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (1.26.4)
# Requirement already satisfied: packaging>=23.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (23.2)
# Requirement already satisfied: parfive>=2.0.0 in /home/adithya/.local/lib/python3.10/site-packages (from parfive[ftp]>=2.0.0->sunpy[all]) (2.0.2)
# Requirement already satisfied: pyerfa>=2.0.0.1 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (2.0.1.1)
# Requirement already satisfied: requests>=2.28.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (2.32.3)
# Requirement already satisfied: astropy-iers-data>=0.2024.8.27.10.28.29 in /home/adithya/.local/lib/python3.10/site-packages (from astropy>=5.3.0->sunpy[all]) (0.2024.10.14.0.32.55)
# Requirement already satisfied: PyYAML>=3.13 in /usr/lib/python3/dist-packages (from astropy>=5.3.0->sunpy[all]) (5.4.1)
# Requirement already satisfied: tqdm>=4.27.0 in /home/adithya/.local/lib/python3.10/site-packages (from parfive>=2.0.0->parfive[ftp]>=2.0.0->sunpy[all]) (4.66.1)
# Requirement already satisfied: aiohttp in /home/adithya/.local/lib/python3.10/site-packages (from parfive>=2.0.0->parfive[ftp]>=2.0.0->sunpy[all]) (3.9.1)
# Requirement already satisfied: aioftp>=0.17.1 in /home/adithya/.local/lib/python3.10/site-packages (from parfive[ftp]>=2.0.0->sunpy[all]) (0.21.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/adithya/.local/lib/python3.10/site-packages (from requests>=2.28.0->sunpy[all]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.28.0->sunpy[all]) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.28.0->sunpy[all]) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.28.0->sunpy[all]) (2020.6.20)
# Requirement already satisfied: opencv-python>=4.6.0.66 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (4.9.0.80)
# Requirement already satisfied: scikit-image>=0.19.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (0.22.0)
# Requirement already satisfied: asdf-astropy>=0.4.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (0.7.1)
# Requirement already satisfied: asdf>=2.13.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (4.1.0)
# Requirement already satisfied: spiceypy>=5.0.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (6.0.0)
# Requirement already satisfied: glymur>=0.11.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (0.13.8)
# Requirement already satisfied: lxml!=5.0.0,>=4.9.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (4.9.3)
# Requirement already satisfied: asdf-standard>=1.1.0 in /home/adithya/.local/lib/python3.10/site-packages (from asdf>=2.13.0->sunpy[all]) (1.1.1)
# Requirement already satisfied: asdf-transform-schemas>=0.3 in /home/adithya/.local/lib/python3.10/site-packages (from asdf>=2.13.0->sunpy[all]) (0.5.0)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /home/adithya/.local/lib/python3.10/site-packages (from asdf>=2.13.0->sunpy[all]) (7.0.0)
# Requirement already satisfied: jmespath>=0.6.2 in /home/adithya/.local/lib/python3.10/site-packages (from asdf>=2.13.0->sunpy[all]) (1.0.1)
# Requirement already satisfied: semantic_version>=2.8 in /home/adithya/.local/lib/python3.10/site-packages (from asdf>=2.13.0->sunpy[all]) (2.10.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/adithya/.local/lib/python3.10/site-packages (from asdf>=2.13.0->sunpy[all]) (23.1.0)
# Requirement already satisfied: asdf-coordinates-schemas>=0.3 in /home/adithya/.local/lib/python3.10/site-packages (from asdf-astropy>=0.4.0->sunpy[all]) (0.3.0)
# Requirement already satisfied: scipy>=1.8 in /home/adithya/.local/lib/python3.10/site-packages (from scikit-image>=0.19.0->sunpy[all]) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /home/adithya/.local/lib/python3.10/site-packages (from scikit-image>=0.19.0->sunpy[all]) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/adithya/.local/lib/python3.10/site-packages (from scikit-image>=0.19.0->sunpy[all]) (11.0.0)
# Requirement already satisfied: imageio>=2.27 in /home/adithya/.local/lib/python3.10/site-packages (from scikit-image>=0.19.0->sunpy[all]) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/adithya/.local/lib/python3.10/site-packages (from scikit-image>=0.19.0->sunpy[all]) (2023.12.9)
# Requirement already satisfied: lazy_loader>=0.3 in /home/adithya/.local/lib/python3.10/site-packages (from scikit-image>=0.19.0->sunpy[all]) (0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/adithya/.local/lib/python3.10/site-packages (from aiohttp->parfive>=2.0.0->parfive[ftp]>=2.0.0->sunpy[all]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/adithya/.local/lib/python3.10/site-packages (from aiohttp->parfive>=2.0.0->parfive[ftp]>=2.0.0->sunpy[all]) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/adithya/.local/lib/python3.10/site-packages (from aiohttp->parfive>=2.0.0->parfive[ftp]>=2.0.0->sunpy[all]) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/adithya/.local/lib/python3.10/site-packages (from aiohttp->parfive>=2.0.0->parfive[ftp]>=2.0.0->sunpy[all]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/adithya/.local/lib/python3.10/site-packages (from aiohttp->parfive>=2.0.0->parfive[ftp]>=2.0.0->sunpy[all]) (4.0.3)
# Requirement already satisfied: beautifulsoup4>=4.11.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (4.12.2)
# Requirement already satisfied: drms>=0.7.1 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (2.8.2)
# Requirement already satisfied: zeep>=4.1.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (4.2.1)
# Requirement already satisfied: matplotlib>=3.5.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (3.8.2)
# Requirement already satisfied: mpl-animators>=1.0.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (1.1.1)
# Requirement already satisfied: reproject>=0.9.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (0.13.0)
# Requirement already satisfied: cdflib!=1.0.0,>=0.4.4 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (1.3.3)
# Requirement already satisfied: h5netcdf>=1.0.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (1.3.0)
# Requirement already satisfied: h5py>=3.7.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (3.10.0)
# Requirement already satisfied: pandas>=1.4.0 in /home/adithya/.local/lib/python3.10/site-packages (from sunpy[all]) (2.1.4)
# Requirement already satisfied: soupsieve>1.2 in /home/adithya/.local/lib/python3.10/site-packages (from beautifulsoup4>=4.11.0->sunpy[all]) (2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=4.11.4->asdf>=2.13.0->sunpy[all]) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/adithya/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->sunpy[all]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/adithya/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->sunpy[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/adithya/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->sunpy[all]) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/adithya/.local/lib/python3.10/site-packages (from matplotlib>=3.5.0->sunpy[all]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.5.0->sunpy[all]) (2.4.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.4.0->sunpy[all]) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/adithya/.local/lib/python3.10/site-packages (from pandas>=1.4.0->sunpy[all]) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->sunpy[all]) (1.16.0)
# Requirement already satisfied: astropy-healpix>=0.6 in /home/adithya/.local/lib/python3.10/site-packages (from reproject>=0.9.0->sunpy[all]) (1.0.2)
# Requirement already satisfied: dask>=2021.8 in /home/adithya/.local/lib/python3.10/site-packages (from dask[array]>=2021.8->reproject>=0.9.0->sunpy[all]) (2023.12.1)
# Requirement already satisfied: cloudpickle in /home/adithya/.local/lib/python3.10/site-packages (from reproject>=0.9.0->sunpy[all]) (3.0.0)
# Requirement already satisfied: zarr in /home/adithya/.local/lib/python3.10/site-packages (from reproject>=0.9.0->sunpy[all]) (2.16.1)
# Requirement already satisfied: fsspec in /home/adithya/.local/lib/python3.10/site-packages (from reproject>=0.9.0->sunpy[all]) (2023.12.2)
# Requirement already satisfied: isodate>=0.5.4 in /home/adithya/.local/lib/python3.10/site-packages (from zeep>=4.1.0->sunpy[all]) (0.6.1)
# Requirement already satisfied: platformdirs>=1.4.0 in /home/adithya/.local/lib/python3.10/site-packages (from zeep>=4.1.0->sunpy[all]) (4.1.0)
# Requirement already satisfied: requests-toolbelt>=0.7.1 in /home/adithya/.local/lib/python3.10/site-packages (from zeep>=4.1.0->sunpy[all]) (1.0.0)
# Requirement already satisfied: requests-file>=1.5.1 in /home/adithya/.local/lib/python3.10/site-packages (from zeep>=4.1.0->sunpy[all]) (1.5.1)
# Requirement already satisfied: click>=8.1 in /home/adithya/.local/lib/python3.10/site-packages (from dask>=2021.8->dask[array]>=2021.8->reproject>=0.9.0->sunpy[all]) (8.1.7)
# Requirement already satisfied: partd>=1.2.0 in /home/adithya/.local/lib/python3.10/site-packages (from dask>=2021.8->dask[array]>=2021.8->reproject>=0.9.0->sunpy[all]) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in /home/adithya/.local/lib/python3.10/site-packages (from dask>=2021.8->dask[array]>=2021.8->reproject>=0.9.0->sunpy[all]) (0.12.0)
# Requirement already satisfied: asciitree in /home/adithya/.local/lib/python3.10/site-packages (from zarr->reproject>=0.9.0->sunpy[all]) (0.3.3)
# Requirement already satisfied: fasteners in /usr/lib/python3/dist-packages (from zarr->reproject>=0.9.0->sunpy[all]) (0.14.1)
# Requirement already satisfied: numcodecs>=0.10.0 in /home/adithya/.local/lib/python3.10/site-packages (from zarr->reproject>=0.9.0->sunpy[all]) (0.12.1)
# Requirement already satisfied: locket in /home/adithya/.local/lib/python3.10/site-packages (from partd>=1.2.0->dask>=2021.8->dask[array]>=2021.8->reproject>=0.9.0->sunpy[all]) (1.0.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### **Basics of image analysis**
# Let's import required packages and list the available fits images

# %%
from sunpy.map import Map
import matplotlib.pyplot as plt
import astropy.units as u
from colormap import filterColor


img_dir='/home/adithya/Downloads/Sampl1_Jun16'

import glob #to list all files in the folder

print(glob.glob(img_dir+'*.fits')) #all available images in the folder
# Out:
# []

# %% [markdown]
# Open the FITS file. Set SUIT color maps.

# %%
filename= '/home/adithya/Downloads/Sampl1_Jun16/SUT_T24_0847_000413_Lev1.0_2024-06-17T00.16.39.568_0971NB04.fits'

suit_map=Map(filename)
suit_map.peek( cmap= filterColor['NB04'],clip_interval=(1, 99.99)*u.percent )
header= suit_map.fits_header

# %% [markdown]
# ### List the image header parameters

# %%
header= suit_map.fits_header
print(header.keys) #Prints each keyword to a new line
# Out:
# <bound method Header.keys of SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                   16 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 4096 / lines in image
# NAXIS2  =                 4096 / pixels in a line
# EXTEND  =                    T
# GRT_DT  = '2024-06-18T05:50:08.445' / GRT Time
# DHOBT_DT= '2024-06-17T00:16:39.56820000' / UTC time with respect to DHOBT
# FRM_CNT =                 2934 / Frame counter
# DHOBTCNT=         904296220482 / DHOBT Counter Clock
# SDRAM   =           1663434752 / SDRAM Headers
# PACKET  =           4188285873 / Header identifier
# IMGTRID =                25381 / Image Transfer ID
# FW1POS  =                    0 / Filter Wheel 1 Position
# X1      =                   20 / X1 position
# FW2POS  =                    0 / Filter Wheel 2 Position
# Y1      =                    0 / Y1 position
# ROFREQ  =                  280 / Readout Frequency in KHz
# BIN_EN  = 'disable '           / Binning Enable or Disable
# CCD_DUMP=                    1 / Number of CCD Dumps
# ROI_FF  = 'Full Frame'         / ROI or Full Frame
# SHTR_OP =               989753 / Shutter opening time in milliseconds
# IMG_TRAN=               993041 / Image Transfer time in milliseconds
# CMD_EXPT=                 2000 / Commanded Exposure time in milliseconds
# IMG_TYPE= 'Normal  '           / Image Type
# OBS_MODE=                  151 / Observation mode
# ROI_ID  =                   27 / ROI Identifier
# SOLX1TR =                    0 / SOLEX 1 Trigger
# SOLX2TR =                    0 / SOLEX 2 Trigger
# HELIOSTR=                    0 / HEL1OS Trigger
# FLR_TRIG=             78094342 / External Flare Trigger time in milliseconds
# REJ_BIT =                    0 / Not Applicable
# SHTR_STR=          179.6484375 / Shutter Start Position in Degrees
# CCD_RDOM= '4 output mode(EFGH)' / CCD Read Output Mode
# SHTR_STO=            0.3515625 / Shutter Stop Position in Degrees
# ROI_M_EN=                    1 / ROI tracking Enable or Disable
# SHTR_HTE=                    0 / Shutter Home Timeout Error
# EXP_NIR =                    0 / Exposure LUT not in range
# EXP_ND8 =                    0 / Exp_address_not_divisible by 8
# ROI_ND16=                    0 / ROI_coordinates_not_divisible by 16
# ROI_CHKM=                    0 / ROI checksum mismatch
# NORM_FLR=                    0 / Normal flare
# PROM_FLR=                    0 / Prominance flare
# ER_FL_E =                    0 / Data from E channel is more than expected error
# ER_FL_F =                    0 / Data from F channel is more than expected error
# ER_FL_G =                    0 / Data from G channel is more than expected error
# ER_FL_H =                    0 / Data from H channel is more than expected error
# ER_FL_DL=                    0 / Data is less than expected
# SHTR_TRQ= '1/8 Micro-Stepping Low Torque' / Shutter torque
# FL_SELF =                    0 / Self_Trigger_timeout
# FL_EXT  =                    0 / External_Trigger_timeout
# PE_CRC  =                    0 / PE TE fpga CRC error
# BIN_CNTR=                    3 / Bin Counter
# LIN_ENC =              -4053.5 / Linear encoder value in microns
# FLR_ED  =                   15 / Helios & Solex1 & Solex0 & Self_trig
# TRK_ED  =                    1 / Tracking Enable/Disable
# OB_ED   =                    0 / mux selection in the TE
# LED_DAC1=              3.28125 / LED DAC1 current in mA
# LED_DAC2=             5.234375 / LED DAC2 current in mA
# LED_DAC3=              0.15625 / LED DAC3 current in mA
# LED_DAC4=              3.28125 / LED DAC4 current in mA
# AMP_G_E = '3.04    '           / Amplifier gain of channel E
# AMP_G_F = '3.09    '           / Amplifier gain of channel F
# AMP_G_G = '3.01    '           / Amplifier gain of channel G
# AMP_G_H = '2.95    '           / Amplifier gain of channel H
# OVERSCAN=                   14 / Number of overscan pixels
# OD_BIAS =        24.7365234375 / Output Drain Voltage in Volts
# RD_BIAS =         16.475390625 / Reset Drain Voltage in Volts
# DD_BIAS =           21.7578125 / Common Drain Voltage in Volts
# OG_BIAS =           1.98046875 / Output Gate Voltage in Volts
# OFFSET1 =                  138 / DAC offset value for channel E
# OFFSET2 =                  134 / DAC offset value for channel F
# OFFSET3 =                  139 / DAC offset value for channel G
# OFFSET4 =                  133 / DAC offset value for channel H
# LEDONOFF= '4427    '           / LED ON/OFF status in HEX(0 = OFF,1=ON)
# SEQ_IDF =                    0 / Sequence Identifier
# S_PIX_V =              2850000 / Superpixel Value
# S_PIX_S =                    0 / Superpixel Number
# MEAS_EXP=   1929.7000000000003 / Measured exposure in milliseconds
# MFGDATE = '2024-09-08T18:32:24.280011' / Time of making the image file
# IMGNUM  =                  105 / Image number in the packet
# FOLDNAME= 'SUTXXN18P1AL10020008NNNN24170054817758_T24_0847_000413_V1_1' / Data p
# FTR_NAME= 'NB04    '           / Filter Combination Name
# T_OBS   = '2024-06-17T00:16:39.56820000' / Observation time
# DATE-OBS= '2024-06-17T00:16:39.56820000' / Observation date
# F_NAME  = 'SUT_T24_0847_000413_Lev1.0_2024-06-17T00.16.39.568_0971NB04.fits' / F
# PROP_ID = 'T24_0847'           / Proposal ID
# OBS_ID  = 'T24_0847_000413'    / Observation ID
# F_VER   = 'V1_1    '           / File Version
# F_LEVEL = 'Lev1.0  '           / Level of the file
# QVAL    =                100.0 / Percentage of quality for image
# QDESC   = 'Complete Image'     / Quality description
# OBS_STRT= '2024-06-17T00:16:39.56820000' / Observation start time
# OBS_STP = '2024-06-17T00:16:39.56820000' / Observation stop time
# X2      =                 4096 / X2 position
# Y2      =                 4096 / Y2 position
# TOTSHTRT=    2574.531685185185 / Total Shutter Movement time
# RM_OVER =                    1 / Overscan removal status [1=YES,0=NO]
# IN_OSCOR=                    1 / In-situ overscan correction status [1=YES,0=NO]
# GAINCOR =                    1 / Gain correction status [1=YES,0=NO]
# NORM    = '0       '           / Is this file normalized? [1=YES,0=NO]
# FIR_ROT =                    1 / First rotation status [1=YES,0=NO]
# MASTER  = '0       '           / Is this a master calibration file? [1=YES,0=NO]
# FLAT_CF = 'master_flat_2024-05-24.fits' / Flat calibration file name
# SCAT_CF = 'NB04_scat_0_velc_2024-06-01.fits' / Scatter calibration file name
# PRNU_CF = 'master_prnu_255_common_2023-06-01.fits' / PRNU calibration file name
# DIST_CF = 'NA      '           / Distortion correction file name
# PSF_CF  = 'NA      '           / PSF calibration file name
# NSPIKES =                    0 / Number of spikes detected
# MBIAS_E =                    0 / Mean bias - E
# MBIAS_F =                    0 / Mean bias - F
# MBIAS_G =                    0 / Mean bias - G
# MBIAS_H =                    0 / Mean bias - H
# MISSION = 'Aditya-L1'          / Mission Name
# PNAME   = 'SUIT    '           / Payload Name
# DESCR   = 'Remote Sensing'     / Description of SUIT
# CTYPE1  = 'HPLN-TAN'           / Projection name
# CUNIT1  = 'arcsec  '           / Axis unit
# CDELT1  =                0.698 / Pixel size in x
# CTYPE2  = 'HPLT-TAN'           / Projection name
# CUNIT2  = 'arcsec  '           / Axis unit
# CDELT2  =                0.698 / Pixel size in y
# CROTA2  =    7.096082885992894 / Rotation angle about reference pixel
# CRPIX1  =               2574.8 / Sun Centre X position in Pixels
# CRPIX2  =               1201.2 / Sun Centre Y position in Pixels
# CRVAL1  =                    0 / Location of reference pixel in x-direction (arc
# CRVAL2  =                    0 / Location of reference pixel in y-direction (arc
# R_SUN   =               1373.8 / Radius of the sun in pixels
# HGLT_OBS=   1.2695088158009724 / Stoneyhurst heliograp. lat. of observer (deg)
# HGLN_OBS=  0.13304855156458087 / Stoneyhurst heliograp. long. of observer (deg)
# CRLT_OBS=   1.2695088158009724 / Carrington latitude of the observer (deg)
# GAEX_OBS=  -10212867.281304408 / Geocentric Inertial X position in Km
# GAEY_OBS=  -150351100.98838225 / Geocentric Inertial Y position in Km
# GAEZ_OBS=   -78871.45216912079 / Geocentric Inertial Z position in Km
# HAEX_OBS=  -10212867.281304408 / Heliocentric Inertial X position in Km
# HAEY_OBS=  -150351100.98838225 / Heliocentric Inertial Y position in Km
# HAEZ_OBS=   -78871.45216912079 / Heliocentric Inertial Z position in Km
# DSUN_OBS=   150697586.06968537 / Distance from Sun center to Aditya in Km
# DSUN_REF=    151978929.4734249 / Distance from Sun center to Earth in Km
# RSUN_REF=             695700.0 / Reference radius of the Sun in Km
# P_ANGLE =    7.096082885992894 / P angle in degrees
# ROLL    =    66.56212588615396 / Roll angle in degrees
# YAW     =    23.44295284784789 / Yaw angle in degrees
# PITCH   =     89.5391226047948 / Pitch angle in degrees
# SW1     =                  7.0 / 3708_SUIT_1553_WORD-1
# SW2     =                  6.0 / 3709_SUIT_1553_WORD-2
# SW3     =                250.0 / 3723_SUIT_1553_WORD-3
# SW4     =                204.0 / 3724_SUIT_1553_WORD-4
# SW5     =                  0.0 / 3725_SUIT_1553_WORD-5
# SW6     =                  4.0 / 3726_SUIT_1553_WORD-6
# SW7     =                  0.0 / 4168_SUIT_1553_WORD-7
# SW8     =                243.0 / 4172_SUIT_1553_WORD-8
# SW9     =                  2.0 / 4202_SUIT_1553_WORD-9
# SW10    =                158.0 / 4207_SUIT_1553_WORD-10
# SW11    =                135.0 / 4208_SUIT_1553_WORD-11
# SW12    =                 72.0 / 4209_SUIT_1553_WORD-12
# SW13    =                 27.0 / 4210_SUIT_1553_WORD-13
# SW14    =                  0.0 / 4211_SUIT_1553_WORD-14
# SW15    =                  0.0 / 4212_SUIT_1553_WORD-15
# SW16    =                  1.0 / 4213_SUIT_1553_WORD-16
# SW17    =                  0.0 / 4214_SUIT_1553_WORD-17
# SW19    =                151.0 / 4216_SUIT_1553_WORD-19
# SW20    =                  0.0 / 4217_SUIT_1553_WORD-20
# SW21    =                  0.0 / 4218_SUIT_1553_WORD-21
# SW22    =                  0.0 / 4219_SUIT_1553_WORD-22
# SW23    =                 43.0 / 4220_SUIT_1553_WORD-23
# SW24    =                124.0 / 4221_SUIT_1553_WORD-24
# SW25    =                  0.0 / 4222_SUIT_1553_WORD-25
# SW26    =                 85.0 / 4223_SUIT_1553_WORD-26
# SW27    =                  0.0 / 4224_SUIT_1553_WORD-27
# SW28    =                106.0 / 4225_SUIT_1553_WORD-28
# SW29    =                128.0 / 4226_SUIT_1553_WORD-29
# SW30    =                232.0 / 4227_SUIT_1553_WORD-30
# SW31    =                  0.0 / 4228_SUIT_1553_WORD-31
# SW32    =                 30.0 / 4229_SUIT_1553_WORD-32
# DCNTC1R =               -55.09 / 5271_SUIT_DET_CF_NHP_TEMP_CPRT1-R
# DHNTC1  =               -63.22 / 5275_SUIT_DHA-HP_NCF_TEMP_CPRT1
# DMTTC2R =               -59.76 / 5276_SUIT_DET_MNT_TEMP_CPRT2-R
# DHTC2R  =               -67.29 / 5277_SUIT_DHA-HP_TEMP_CPRT2-R
# DCNTF1R =               -53.03 / 5335_SUIT_DET_CF_NHP_TEMP_FPRT1-R
# RLTF1   =               -53.03 / 5337_SUIT_RADIATOR-L2_TEMP_FPRT1
# DHNTF1  =               -53.03 / 5339_SUIT_DHA-HP_NCF_TEMP_FPRT1
# DMTF2R1 =               -59.52 / 5340_SUIT_DET_MNT_TEMP_FPRT2-R
# DHTF2R1 =               -66.73 / 5341_SUIT_DHA-HP_TEMP_FPRT2-R
# DMTF2R2 =               -47.23 / 5342_SUIT_DET_MNT_TEMP_FPRT2-R
# DHTF2R2 =               -47.23 / 5343_SUIT_DHA-HP_TEMP_FPRT2-R
# FD2TT   =                 30.5 / 6811_SUIT_FW_DRIVE-2_TEMP_THR
# SMTTR   =               76.634 / 6815_SUIT_SHUTER_MOT_TEMP_TCPL-R
# FWMTT   =                 22.0 / 11514_SUIT_FW_MNT_TEMP_THR
# SHUMTT  =                 24.0 / 11529_SUIT_SHUTTER_MNT_TEMP_THR
# DHAM1TT =                 21.0 / 11607_SUIT_DHA_MNT-1_TEMP_THR
# DHAM2TT =                 22.0 / 11617_SUIT_DHA_MNT-2_TEMP_THR
# FD1TT   =                 33.0 / 11623_SUIT_FW_DRIVE-1_TEMP_THR
# FCLAMTT =                 21.0 / 11640_SUIT_FCLA_MNT_TEMP_THR
# ELX_THR =                 35.5 / 11686_SUIT_ELX_TEMP_THR
# THFMTT  =                 23.5 / 11702_SUIT_TH-FLTR_MNT_TEMP_THR
# DMTC2M  =               -59.76 / 11771_SUIT_DET_MNT_TEMP_CPRT2-M
# DHTC2M  =               -65.42 / 11772_SUIT_DHA-HP_TEMP_CPRT2-M
# DCNTF2M =               -56.36 / 11781_SUIT_DET_CF_NHP_TEMP_FPRT2-M
# OBNTTF  =                 21.4 / 11783_SUIT_OB_NEAR_TF_TEMP_FTS
# OBNSTF  =                22.29 / 11793_SUIT_OB_NEAR_SHTR_TEMP_FTS
# DCNTC2M =               -57.23 / 11834_SUIT_DET_CF_NHP_TEMP_CPRT2-M
# DMTF2M  =               -59.52 / 11840_SUIT_DET_MNT_TEMP_FPRT2-M
# DHTF2M  =               -64.99 / 11844_SUIT_DHA-HP_TEMP_FPRT2-M
# DBTFM   =                23.51 / 11851_SUIT_DHA-BCVR_TEMP_FTS-M
# OBNM2TF =                21.18 / 11855_SUIT_OB_NEAR_M2_TEMP_FTS
# OBNDTF  =                20.62 / 11856_SUIT_OB_NEAR_DHA_TEMP_FTS
# SHUMTTM =               88.918 / 11878_SUIT_SHUTER_MOT_TEMP_TCPL-M
# RESTRPOS=           0.52734372 / 4230_SUIT_RESOLVER_START_POS
# RESTPPOS=         179.47264604 / 4231_SUIT_RESOLVER_STOP_POS
# HKFW2POS=                  1.0 / 4343_SUIT_FW-2_POS
# HKFW1POS=                  4.0 / 4344_SUIT_FW-1_POS
# SEQNUM  =                  1.0 / 4386_SUIT_SEQ_NO
# CYCNUM  =                  8.0 / 4387_SUIT_CYCLE_NO
# SECMDID =                 72.0 / 4383_SUIT_SUCCESS_EXE_CMD_ID
# HKROIID =                 27.0 / 4384_SUIT_ROI_ID
# FW2CURS =              -0.0749 / 4568_SUIT_FW2_MTR_CURR_SINE
# FW2CURC =                0.085 / 4569_SUIT_FW2_MTR_CURR_COSINE
# FW1CURS =              -0.0905 / 4572_SUIT_FW1_MTR_CURR_SINE
# FW1CURC =                0.052 / 4573_SUIT_FW1_MTR_CURR_COSINE
# FW1DCDC =             14.59571 / 4574_SUIT_FW1_DCDC_15V_MON
# DM1TEMP =                2.644 / 4566_SUIT_DHA_MOUNT1_TEMP
# DBTTR   =                 24.0 / 11718_SUIT_DHA-BCVR_TEMP_THR-R
# ACQENA  =                  1.0 / 912_SUIT_ACQ_ENA
# FRMSIZE =                  1.0 / 4372_SUIT_FRAME_SIZE
# COMPINC =                  1.0 / 911_SUIT_COMP_INC
# HLACQEN =                  1.0 / 910_SUIT_HELIOS_ACQ_ENA
# FFEXTTO =                  0.0 / 4367_SUIT_FIND_FLARE_EXT_TIMEOUT
# FFSELFTO=                  0.0 / 4366_SUIT_FIND_FLARE_SELF_TIMEOUT
# AUXACQ  =                  1.0 / 913_SUIT_AUX_ACQ_ENA
# FW2MSTS =                  1.0 / 4232_SUIT_FW-2_MOTOR_STS
# PRMFLG  =                  0.0 / 4363_SUIT_PROMINANCE_FLARE_FLAG
# PLSTS   =                  1.0 / 4382_SUIT_P/L_STS
# PGEXFLG =                  1.0 / 4381_SUIT_PROG_EXE_FLAG
# CCDSTS  =                  1.0 / 4380_SUIT_CCD_STS
# BINSTS  =                  0.0 / 4373_SUIT_BINNING_STS
# SX2FLG  =                  0.0 / 4360_SUIT_SOLEXS-2_FLARE_FLAG
# FW1MSTS =                  1.0 / 4342_SUIT_FW-1_MOTOR_STS
# PPMSTS  =                  0.0 / 4561_SUIT_PINPULLER_M_STS
# SMONSTS =                  1.0 / 4562_SUIT_SHUTTER_MTR_ON_STS
# PPRSTS  =                  0.0 / 4559_SUIT_PINPULLER_R_STS
# NRMFLG  =                  0.0 / 4364_SUIT_NORMAL_FLARE_FLAG
# PPMARM  =                  0.0 / 4560_SUIT_PINPULLER_M_ARM_STS
# ENCONS  =                  0.0 / 4564_SUIT_ENCODER_ON_STS
# SX1FLG  =                  0.0 / 4361_SUIT_SOLEXS-1_FLARE_FLAG
# PPRARM  =                  0.0 / 4558_SUIT_PINPULLER_R_ARM_STS
# PZOONS  =                  0.0 / 4563_SUIT_PIEZO_MTR_ON_STS
# CRTIME  = '2024-06-17T00:16:39' / Time of Sun Centre information
# RSUN_OBS=    958.9123999999999 / Calculated Sun radius in arcsecs
# SUN_CX  =               2574.8 / Sun center x-position (pixel)
# SUN_CY  =               1201.2 / Sun center y-position (pixel)
# BZERO   =                30000
# BSCALE  =                    1
# WAVELNTH=                 2803 / Wavelength of the filter
# EXPTIME =                  2.0 / Exposure in seconds
# SPIKERM =                    0 / Spike removal status [1=YES, 0=NO]
# COBWEBRM=                    0 / Cobweb removal status [1=YES, 0=NO]
# OBSDESC = 'Full Disk'          / Feature/Type of observation
# TIMEUNIT= 's       '           / Unit of Exposure [EXPTIME]
# WAVEUNIT= 'angstrom'           / Unit of Wavelength [WAVELNTH]
# FSIZE_KB=           32790.9375 / File size in KB
# SFT_VER = 'V1.0    '           / Software version
# REMARKS = 'Created by SUIT-POC, IUCAA, Pune' / Remarks
# CHECKSUM= 'HCaaJCWRHCaXHCWX'   / HDU checksum updated 2024-12-31T10:53:04
# DATASUM = '508008487'          / data unit checksum updated 2024-12-31T10:53:04
# COMMENT
# HISTORY                                                                         >

# %% [markdown]
# ### Visualize images as SunPy maps

# %%
import astropy.units as u
import matplotlib

suit_map.plot_settings['cmap'] =  filterColor['NB04']
fig = plt.figure()
ax = fig.add_subplot(projection=suit_map)
suit_map.plot(axes=ax, clip_interval=(1, 99.99)*u.percent)
suit_map.draw_limb(axes=ax)
suit_map.draw_grid(axes=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 4
#       1 import astropy.units as u
#       2 import matplotlib
# ----> 4 suit_map.plot_settings['cmap'] =  filterColor['NB04']
#       5 fig = plt.figure()
#       6 ax = fig.add_subplot(projection=suit_map)
#
# NameError: name 'suit_map' is not defined

# %% [markdown]
# ### Check specific FITS header keys

# %%
exp_time= header["CMD_EXPT"]
print("Exposure time in ms= ", exp_time)

cen_x= header["CRPIX1"]
cen_y= header["CRPIX2"]
print("Center of the image= ", cen_x, cen_y)

radius= header["R_SUN"]
print("Radius of the Sun= ", radius)

Map_rot= header["CROTA2"]
print("Rotation of the image= ", Map_rot)
# Out:
# Exposure time in ms=  2000
# Center of the image=  2574.8 1201.2
# Radius of the Sun=  1373.8
# Rotation of the image=  7.096082885992894

# %% [markdown]
# ### Image as a MATRIX
#
# The image is loaded as a 2D array of numbers. This is stored as a numpy array. This array can be plotted using matplotlib.

# %%
data= suit_map.data
print(data.shape)
print(data)
# Out:
# (4096, 4096)
# [[ -39.  -69.  -65. ...  -40.  -24.  -45.]
#  [ -50.  -90. -101. ...  -13.  -24.  -30.]
#  [ -46.  -83.  -53. ...  -45.  -22.  -31.]
#  ...
#  [ -39.  -81.  -61. ...  -89. -112.  -72.]
#  [ -23.  -40.  -79. ...  -54. -109.  -68.]
#  [  -8.  -64.  -24. ...  -90. -119.  -48.]]

# %%
plt.figure()
plt.imshow(data, vmin=0, vmax= 2.5e4, cmap=filterColor['NB04'], origin='lower')
plt.show()

# %% [markdown]
# ### Cropping image

# %%
data_crop= data[400:800, 2200:2700] #row,col
plt.imshow(data_crop, cmap= filterColor['NB04'], origin='lower')

# %% [markdown]
# Finding the Min, Max, Mean, Standard Deviation of the Cropped Array

# %%
import numpy as np
min_val= np.min(data_crop)
max_val= np.max(data_crop)
print(min_val, max_val)
# Out:
# 4197.0 29727.0

# %% [markdown]
# **Create a mask for Plage regions**
#
# Mask all values that are below 13500. This is a binary array.

# %%
mask_plage= data_crop>13500
plt.imshow(mask_plage, origin='lower')

# %% [markdown]
# Multiply the binary array with the image array to get the pixels from plage regions.

# %%
plage= mask_plage*data_crop
plt.imshow(plage, vmin=0, vmax=2.5e4, cmap=filterColor['NB04'], origin='lower')

# %% [markdown]
# **Create a mask for Quiet Sun regions**
#
# Note that Quiet Sun regions are brighter than sun spots, but dimmer than plages. So, pixels brighter than 8000 but dimmer than 13500 should be chosen. & operator is used to combine two binary arrays.

# %%
mask_qs=  (data_crop < 13500) & (data_crop > 8000) #Combine two different binary masks
plt.imshow(mask_qs, origin='lower')

# %% [markdown]
# Quiet sun mask, when multiplied with the image array gives the values for the quiet sun pixels.

# %%
qs= mask_qs*data_crop #Multiply binary mask with data_crop to get quiet sun pixels
plt.imshow(qs, cmap='gist_heat', origin='lower')
plt.colorbar()

# %% [markdown]
# **Finding the brightness ratio of plage regions compared to quiet sun regions.**
#
# The total intensity of plage regions and quiet sun regions is computed. The total values are divided by the number of non zero pixels in the respective masks to get the mean brightness.
#
# NOTE: np.mean() cannot be used here, as this will divide the sum of values with the total number of pixels in the frame. Not with the number of non-zero pixels.

# %%
qs_mean= np.sum(qs)/ np.count_nonzero(qs) #np.count_nonzero() counts the number of non zero pixels in the array.
plage_mean= np.sum(plage)/ np.count_nonzero(plage)
print(plage_mean/qs_mean)
# Out:
# 1.6409553297863197

# %% [markdown]
# ### Visualizing Limb Darkening

# %%
NB6_map=Map('/home/adithya/Downloads/Oct30/SUT_T24_1591_000631_Lev1.0_2024-10-30T06.33.07.744_0971NB06.fits')
NB6_map.peek()

# %% [markdown]
# Header details

# %%
nb6_header=NB6_map.fits_header
row_cen,col_cen=nb6_header['CRPIX1'],nb6_header['CRPIX2']
print(row_cen,col_cen)
# Out:
# 2069.6 2069.9

# %%
NB6_data= NB6_map.data
plt.figure()
plt.imshow(NB6_data, vmin=0, cmap='gray', origin='lower')
plt.grid()
plt.show()

# %% [markdown]
# Intensity profile along the row 2069

# %%
plt.plot(NB6_data[2069]/np.max(NB6_data[2069]))

plt.title("Linear Profile across Sun center")
plt.ylabel("Counts")
plt.xlabel("Pixels")
plt.show()

# %% [markdown]
# Intensity profile along the col 2069

# %%
plt.plot(NB6_data[:,2069]/np.max(NB6_data[:,2069]))

plt.title("Linear Profile across Sun center")
plt.ylabel("Counts")
plt.xlabel("Pixels")
plt.show()

# %% [markdown]
# ### Working HMI data
# Downloading HMI image using fido package

# %%
from sunpy.net import Fido, attrs as a
import astropy.units as u

# Define time range
time_range = a.Time("2024-06-17 00:16", "2024-06-17 00:17")  # Modify as needed
hmi_query = Fido.search(time_range, a.Instrument("HMI"), a.Physobs("LOS_magnetic_field"))

# Download the data
hmi_files = Fido.fetch(hmi_query,path='.')
# Out:
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# hmi.m_45s.2024.06.17_00_17_15_TAI.magnetogram.fits:   0%|          | 0.00/16.1M [00:00<?, ?B/s]

# %%
hmi_map = Map('/home/adithya/Downloads/hmi.m_45s.2024.06.17_00_17_15_TAI.magnetogram.fits')
hmi_map.peek(cmap='hmimag',title='HMI Magnetogram')

# %% [markdown]
# Rotate the HMI map

# %%
hmi_rotated = hmi_map.rotate(order=3)
hmi_rotated.peek(cmap='hmimag',title='HMI Magnetogram Rotated')

# %%
from astropy.coordinates import SkyCoord

tx1, tx2 = -150, 150
ty1, ty2 = -600,-300

coords = SkyCoord(Tx=(tx1, tx2) * u.arcsec, Ty=(ty1,ty2) * u.arcsec, frame=suit_map.coordinate_frame)
suit_box=suit_map.submap(coords)
suit_box.peek(cmap=filterColor['NB04'])

# %%
hmicoords = SkyCoord(Tx=(tx1, tx2) * u.arcsec, Ty=(ty1,ty2) * u.arcsec, frame=hmi_map.coordinate_frame)
hmi_box=hmi_map.submap(hmicoords)
hmi_box.peek(cmap='hmimag')
